# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import pi

np.random.seed(0)
#Generation of data
x1=np.random.normal(loc=(2,0),scale=4,size=(100,2))
x2=np.random.normal(loc=(0,0),scale=2,size=(100,2))
x3=np.random.normal(loc=(-2,0),scale=3,size=(100,2))
X=np.concatenate([x1,x2,x3])

plt.figure()
plt.plot(x1.T[0],x1.T[1],'*',label="Original Data")
plt.plot(x2.T[0],x2.T[1],'*',label="Original Data")
plt.plot(x3.T[0], x3.T[1],'*',label="Original Data")
plt.legend()
plt.title("Generated Data")
plt.savefig("GMM1")

k=2

#Random Initialization
init_mean=X[np.random.choice(X.shape[0], k, replace=False)]
init_variance=[1 for i in range(k)]
init_contribution=[1/k for i in range(k)]

def gaussian_density(x,mean,var):
    return (1/(2*pi*var)**0.5)*np.exp((x-mean)**2/(2*var))
    
#EM
means_global=[]
variations_global=[]
contributions_global=[]
iterations=100
for i in range(iterations):
    means_global[i]=mean
    variations_global[i]=variance
    contributions_global[i]=contribution
    responsibilities=np.zeroes((X.shape[0],k))
    for i in range(X.shape[0]):
        X[0]
# Out:
# 3.141592653589793
